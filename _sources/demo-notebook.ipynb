# %% [markdown]
# # Demo notebook

# %%
# %matplotlib inline
# %load_ext autoreload
# %load_ext watermark


import dask
import distributed
import matplotlib as mpl
import matplotlib.pyplot as plt
import ncar_jobqueue
import numpy as np
import pandas as pd
import xarray as xr
import xgcm

mpl.rcParams["savefig.dpi"] = 300
mpl.rcParams["savefig.bbox"] = "tight"
mpl.rcParams["figure.dpi"] = 180

xr.set_options(keep_attrs=True, display_style="html")

# %watermark -iv
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# numpy        : 1.19.2
# distributed  : 2.30.0
# matplotlib   : 3.3.2
# ncar_jobqueue: 2020.3.4
# xarray       : 0.16.3.dev150+g37522e991
# xgcm         : 0.5.1.dev91+g86c9641
# dask         : 2.30.0
# pandas       : 1.1.3

# %%
cluster = ncar_jobqueue.NCARCluster(
    project="NCGD0048",
    scheduler_options=dict(dashboard_address=":9797"),
)

cluster.scale(4)

client = distributed.Client(cluster)
client
# Out:
# <Client: 'tcp://10.12.205.200:37558' processes=0 threads=0, memory=0 B>

# %% [markdown]
# ## Read one year of daily average data

# %%
path = "/glade/p/nsc/ncgd0048/ETP_1_20/COMPRESSED_OCEAN_DAILY/*_2005_*"
ds = xr.open_mfdataset(path, parallel=True, chunks={"zl": 20}).isel(time=slice(2,None))  
# the first two timesteps are 2004-12-30 and 2004-12-31 for some reason, exclude those
ds
# Out:
# <xarray.Dataset>
# Dimensions:     (nv: 2, time: 363, xh: 1000, xq: 1001, yh: 900, yq: 901, zl: 140)
# Coordinates:
#   * xh          (xh) float64 235.0 235.1 235.1 235.2 ... 284.8 284.9 284.9 285.0
#   * yh          (yh) float64 -14.97 -14.93 -14.88 -14.82 ... 29.88 29.92 29.98
#   * zl          (zl) float64 1.25 3.75 6.25 ... 6.074e+03 6.324e+03 6.475e+03
#   * time        (time) object 2005-01-01 12:00:00 ... 2005-12-29 12:00:00
#   * nv          (nv) float64 1.0 2.0
#   * xq          (xq) float64 235.0 235.1 235.1 235.2 ... 284.9 284.9 284.9 285.0
#   * yq          (yq) float64 -15.0 -14.95 -14.9 -14.85 ... 29.85 29.9 29.95 30.0
# Data variables:
#     thetao      (time, zl, yh, xh) float32 dask.array<chunksize=(1, 20, 900, 1000), meta=np.ndarray>
#     so          (time, zl, yh, xh) float32 dask.array<chunksize=(1, 20, 900, 1000), meta=np.ndarray>
#     uo          (time, zl, yh, xq) float32 dask.array<chunksize=(1, 20, 900, 1001), meta=np.ndarray>
#     vo          (time, zl, yq, xh) float32 dask.array<chunksize=(1, 20, 901, 1000), meta=np.ndarray>
#     average_T1  (time) datetime64[ns] dask.array<chunksize=(1,), meta=np.ndarray>
#     average_T2  (time) datetime64[ns] dask.array<chunksize=(1,), meta=np.ndarray>
#     average_DT  (time) timedelta64[ns] dask.array<chunksize=(1,), meta=np.ndarray>
#     time_bnds   (time, nv) timedelta64[ns] dask.array<chunksize=(1, 2), meta=np.ndarray>
# Attributes:
#     filename:   ocean_daily__2005_001.nc
#     title:      MOM6 diagnostic fields table for CESM case: ETP.003
#     grid_type:  regular
#     grid_tile:  N/A

# %% [markdown]
# ## Plot fields

# %%
monthly = ds.resample(time="M").mean()

# %% [markdown]
# The monthly mean temperature at one depth level is only 46MB. Let's calculate it and save

# %%
monthly.thetao.sel(zl=100, method="nearest").nbytes/1e6
# Out:
# 43.2

# %%
T100 = monthly.thetao.sel(zl=100, method="nearest").load()

# %% [markdown]
# ### Annual mean $T_{100}$

# %%
T100.mean("time").plot(robust=True, cmap=mpl.cm.RdYlBu_r)

# %% [markdown]
# ### Monthly mean $T_{100}$

# %%
(
    T100
    .sel(xh=slice(260, 280), yh=slice(0, 20))  # subset to (260°E→ 280°E), (0°N-20°N)
    .plot(
        col="time",
        col_wrap=3,
        robust=True,  # 2nd, 98th percentile as colormap limits
        cmap=mpl.cm.RdYlBu_r,  # colormap
        cbar_kwargs={"orientation": "horizontal"},  # horizontal colorbar
    )
)
